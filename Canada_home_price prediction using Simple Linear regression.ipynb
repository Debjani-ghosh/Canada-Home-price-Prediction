# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('D:\canada_home_price.csv')
df
# Out:
#     year         price
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
df.head()
# Out:
#    year        price
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
x=df.iloc[:,:1]
x
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y=df.iloc[:,1]
y
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
plt.scatter(x,y,color='red',marker='*')
plt.title("CANADA HOME PRICE")
plt.xlabel("year")
plt.ylabel("price")
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print("x_train",x_train)
print("x_test",x_test)
print("y_train",y_train)
print("y_test",y_test)
# Out:
# x_train     year
# 19  1989
# 36  2006
# 46  2016
# 33  2003
# 23  1993
# 34  2004
# 27  1997
# 21  1991
# 13  1983
# 38  2008
# 17  1987
# 42  2012
# 4   1974
# 28  1998
# 14  1984
# 10  1980
# 41  2011
# 30  2000
# 31  2001
# 40  2010
# 20  1990
# 18  1988
# 25  1995
# 6   1976
# 7   1977
# 44  2014
# 1   1971
# 16  1986
# 0   1970
# 15  1985
# 5   1975
# 11  1981
# 9   1979
# 8   1978
# 12  1982
# 43  2013
# 37  2007
# x_test     year
# 24  1994
# 22  1992
# 39  2009
# 35  2005
# 2   1972
# 3   1973
# 29  1999
# 32  2002
# 45  2015
# 26  1996
# y_train 19    16426.725480
# 36    32738.262900
# 46    34229.193630
# 33    22739.426280
# 23    15875.586730
# 34    25719.147150
# 27    17310.757750
# 21    17266.097690
# 13    10416.536590
# 38    37446.486090
# 17    12974.806620
# 42    42665.255970
# 4      5576.514583
# 28    16622.671870
# 14    10790.328720
# 10     8355.968120
# 41    42334.711210
# 30    18987.382410
# 31    18601.397240
# 40    38420.522890
# ...

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Intercept is",model.intercept_)
print("coefficient is: ",model.coef_)
# Out:
# Intercept is -1710895.0617872213
# coefficient is:  [868.22718531]

# %%
plt.scatter(x,y,color='red',marker='*')
plt.plot(x,model.predict(x),color='green')
plt.xlabel("year")
plt.ylabel("price")
plt.show()

# %%
pred_res=model.predict(x_test)
print("Test year",x_test)
print("predicted price",pred_res)
# Out:
# Test year     year
# 24  1994
# 22  1992
# 39  2009
# 35  2005
# 2   1972
# 3   1973
# 29  1999
# 32  2002
# 45  2015
# 26  1996
# predicted price [20349.94572643 18613.49135581 33373.35350612 29900.44476487
#   1248.94764955  2117.17483487 24691.081653   27295.76320894
#  38582.716618   22086.40009706]

# %%
print(model.predict([[2020]]))
# Out:
# [42923.85254456]

# %%
-1710895.0617872213+868.22718531*2020
# Out:
# 42923.85253897868

# %% [markdown]
# # Price of a home in 2020 is 42923.85254456
